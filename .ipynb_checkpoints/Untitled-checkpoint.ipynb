# %%
import sys
import csv
import glob
import pandas as pd

# get data file names
path =r'E:\Dropbox (Personal)\CodingDropbox\Github\1 codingtemple-july2020\Capstone\Elections\files\GA_November8_2016(CountyPrecinct)'
filenames = glob.glob(path + "/*.xlsx")

dfs = []
for df in dfs: 
    xl_file = pd.ExcelFile(filenames)
    df=xl_file.parse('DEMOGRAPHICS REPORT')
    dfs.concat(df, ignore_index=True)
dfs
# Out:
# []

# %%
import sys
import csv
import glob
import pandas as pd
from os import getcwd, listdir
from os.path import basename

dfs= []
path = r'.\files\GA_November8_2016(CountyPrecinct)'
files = listdir(path)
for i in files:
    dfs.append(path + "/" + i)
print(path, files)

df = []
for f in dfs:
    voter_cols = ['ID','Precinct','BM','BF','BU','WM','WF','WU','APacM','APacF','APacU','HM','HF','HU','NM','NF','NU','OM','OF','OU','UNKNOWN MALE','UNKNOWN FEMALE','UNKNOWN','TOTAL VOTERS']
    column_range = "A,B,C,F,I,L,O,R,U,X,AA,AD,AG,AJ,AM, AP,AS, AV, AY, BB, BE,BH, BK,BN"
    data = pd.read_excel(f, 'DEMOGRAPHICS REPORT', header=None, names=voter_cols, index_col=0,  usecols=column_range, skiprows=3)
    data.index = [basename(f)] * len(data)
    df.append(data)

df = pd.concat(df)
df
# Out:
# .\files\GA_November8_2016(CountyPrecinct) ['APPLING.xlsx', 'ATKINSON.xlsx', 'BACON.xlsx', 'BAKER.xlsx', 'BALDWIN.xlsx', 'BANKS.xlsx', 'BARROW.xlsx', 'BARTOW.xlsx', 'BEN HILL.xlsx', 'BERRIEN.xlsx', 'BIBB.xlsx', 'BLECKLEY.xlsx', 'BRANTLEY.xlsx', 'BROOKS.xlsx', 'BRYAN.xlsx', 'BULLOCH.xlsx', 'BURKE.xlsx', 'BUTTS.xlsx', 'CALHOUN.xlsx', 'CAMDEN.xlsx', 'CANDLER.xlsx', 'CARROLL.xlsx', 'CATOOSA.xlsx', 'CHARLTON.xlsx', 'CHATHAM.xlsx', 'CHATTAHOOCHEE.xlsx', 'CHATTOOGA.xlsx', 'CHEROKEE.xlsx', 'CLARKE.xlsx', 'CLAY.xlsx', 'CLAYTON.xlsx', 'CLINCH.xlsx', 'COBB.xlsx', 'COFFEE.xlsx', 'COLQUITT.xlsx', 'COLUMBIA.xlsx', 'COOK.xlsx', 'COWETA.xlsx', 'CRAWFORD.xlsx', 'CRISP.xlsx', 'DADE.xlsx', 'DAWSON.xlsx', 'DECATUR.xlsx', 'DEKALB.xlsx', 'DODGE.xlsx', 'DOOLY.xlsx', 'DOUGHERTY.xlsx', 'DOUGLAS.xlsx', 'EARLY.xlsx', 'ECHOLS.xlsx', 'EFFINGHAM.xlsx', 'ELBERT.xlsx', 'EMANUEL.xlsx', 'EVANS.xlsx', 'FANNIN.xlsx', 'FAYETTE.xlsx', 'FLOYD.xlsx', 'FORSYTH.xlsx', 'FRANKLIN.xlsx', 'FULTON.xlsx', 'GILMER.xlsx', 'GLASCOCK.xlsx', 'GLYNN.xlsx', 'GORDON.xlsx', 'GRADY.xlsx', 'GREENE.xlsx', 'GWINNETT.xlsx', 'HABERSHAM.xlsx', 'HALL.xlsx', 'HANCOCK.xlsx', 'HARALSON.xlsx', 'HARRIS.xlsx', 'HART.xlsx', 'HEARD.xlsx', 'HENRY.xlsx', 'HOUSTON.xlsx', 'IRWIN.xlsx', 'JACKSON.xlsx', 'JASPER.xlsx', 'JEFF DAVIS.xlsx', 'JEFFERSON.xlsx', 'JENKINS.xlsx', 'JOHNSON.xlsx', 'JONES.xlsx', 'LAMAR.xlsx', 'LANIER.xlsx', 'LAURENS.xlsx', 'LEE.xlsx', 'LIBERTY.xlsx', 'LINCOLN.xlsx', 'LONG.xlsx', 'LOWNDES.xlsx', 'LUMPKIN.xlsx', 'MACON.xlsx', 'MADISON.xlsx', 'MARION.xlsx', 'MCDUFFIE.xlsx', 'MCINTOSH.xlsx', 'MERIWETHER.xlsx', 'MILLER.xlsx', 'MITCHELL.xlsx', 'MONROE.xlsx', 'MONTGOMERY.xlsx', 'MORGAN.xlsx', 'MURRAY.xlsx', 'MUSCOGEE.xlsx', 'NEWTON.xlsx', 'OCONEE.xlsx', 'OGLETHORPE.xlsx', 'PAULDING.xlsx', 'PEACH.xlsx', 'PICKENS.xlsx', 'PIERCE.xlsx', 'PIKE.xlsx', 'POLK.xlsx', 'PULASKI.xlsx', 'PUTNAM.xlsx', 'QUITMAN.xlsx', 'RABUN.xlsx', 'RANDOLPH.xlsx', 'RICHMOND.xlsx', 'ROCKDALE.xlsx', 'SCHLEY.xlsx', 'SCREVEN.xlsx', 'SEMINOLE.xlsx', 'SPALDING.xlsx', 'STEPHENS.xlsx', 'STEWART.xlsx', 'SUMTER.xlsx', 'TALBOT.xlsx', 'TALIAFERRO.xlsx', 'TATTNALL.xlsx', 'TAYLOR.xlsx', 'TELFAIR.xlsx', 'TERRELL.xlsx', 'THOMAS.xlsx', 'TIFT.xlsx', 'TOOMBS.xlsx', 'TOWNS.xlsx', 'TREUTLEN.xlsx', 'TROUP.xlsx', 'TURNER.xlsx', 'TWIGGS.xlsx', 'UNION.xlsx', 'UPSON.xlsx', 'WALKER.xlsx', 'WALTON.xlsx', 'WARE.xlsx', 'WARREN.xlsx', 'WASHINGTON.xlsx', 'WAYNE.xlsx', 'WEBSTER.xlsx', 'WHEELER.xlsx', 'WHITE.xlsx', 'WHITFIELD.xlsx', 'WILCOX.xlsx', 'WILKES.xlsx', 'WILKINSON.xlsx', 'WORTH.xlsx']
#               Precinct   WM   WF  WU   BM   BF  BU  APacM  APacF  APacU  ...  \
# APPLING.xlsx        1B   36   41   0  538  590   1      1      4      0  ...
# APPLING.xlsx        1C    8   14   0  369  395   0      0      0      0  ...
# APPLING.xlsx         2  624  818   0  314  407   0      5      2      0  ...
# APPLING.xlsx        3A    0    1   0  141  154   0      0      0      0  ...
# APPLING.xlsx       3A1    8    6   0  219  230   0      0      0      0  ...
# ...                ...  ...  ...  ..  ...  ...  ..    ...    ...    ...  ...
# WORTH.xlsx    RED ROCK   79  108   0  407  426   0      0      2      0  ...
# WORTH.xlsx       DOLES   15   18   0  175  176   0      0      4      0  ...
# WORTH.xlsx    OAKFIELD   32   36   0   74   68   0      0      2      0  ...
# WORTH.xlsx       88888    0    1   0    0    0   0      0      0      0  ...
# WORTH.xlsx     WARWICK   94  117   0  235  241   0      0      0      0  ...
#
#               NM  NF  NU  OM  OF  OU  UNKNOWN MALE  UNKNOWN FEMALE  UNKNOWN  \
# APPLING.xlsx   1   0   0   4   2   0            15              12        0
# APPLING.xlsx   0   0   0   1   1   0             6              11        0
# APPLING.xlsx   3   0   0   9  10   0            32              19        0
# APPLING.xlsx   0   0   0   0   0   0             1               2        0
# APPLING.xlsx   0   0   0   0   1   0             8               9        0
# ...           ..  ..  ..  ..  ..  ..           ...             ...      ...
# WORTH.xlsx     1   0   0   4   2   0            20              14        0
# WORTH.xlsx     0   0   0   0   2   0             8               7        0
# WORTH.xlsx     0   0   0   0   2   0             4               1        0
# WORTH.xlsx     0   0   0   0   0   0             0               0        0
# WORTH.xlsx     0   0   0   2   1   0             7               2        0
#
#               TOTAL VOTERS
# APPLING.xlsx          1258
# APPLING.xlsx           815
# APPLING.xlsx          2290
# APPLING.xlsx           301
# APPLING.xlsx           482
# ...                    ...
# WORTH.xlsx            1070
# WORTH.xlsx             408
# WORTH.xlsx             219
# WORTH.xlsx               1
# WORTH.xlsx             702
#
# [2826 rows x 23 columns]

# %%
import sys
import csv
import glob
import pandas as pd
from os import getcwd, listdir
from os.path import basename

dfs= []
path = r'.\files\GA_November8_2016(CountyPrecinct)'
files = listdir(path)
for i in files:
    dfs.append(path + "/" + i)
print(path, files)

df = []
totals = []
for f in dfs:
    voter_cols = ['ID','Precinct','BM','BF','BU','WM','WF','WU','APacM','APacF','APacU','HM','HF','HU','NM','NF','NU','OM','OF','OU','UNKNOWN MALE','UNKNOWN FEMALE','UNKNOWN','TOTAL VOTERS']
    column_range = "A,B,C,F,I,L,O,R,U,X,AA,AD,AG,AJ,AM, AP,AS, AV, AY, BB, BE,BH, BK,BN"
    data = pd.read_excel(f, 'DEMOGRAPHICS REPORT', header=None, names=voter_cols, index_col=0,  usecols=column_range, skiprows=3)
    
    indexName = (basename(f[:-5])) + '-' + (data['Precinct'])
    county = (basename(f[:-5]))
#     data.loc[f'{county}-Total'] = data.sum()
    data.index = indexName
    data = data.drop(['Precinct'], axis=1)
    
    data.loc[f'{county}-Total'] = data.sum()
    def population(df):
        df['POW_w_Un_Voters'] = df.drop(['WM','WF','WU','TOTAL VOTERS'], axis=1).sum(axis=1)
        df['POW_wo_Un_Voters'] = df.drop(['WM','WF','WU','UNKNOWN MALE','UNKNOWN FEMALE','UNKNOWN','TOTAL VOTERS','POW_w_Un_Voters'], axis=1).sum(axis=1)
        df['White_Voters'] = df['WM']+df['WF']+df['WU']
        df['POC %'] = round(((df['POW_wo_Un_Voters'] / df['TOTAL VOTERS']) * 100), 2)

    population(data)

    data.to_excel(f'./files/Stripped-Data/{county}_appended.xlsx')
    totals.append(data.loc[f'{county}-Total',:])
    df.append(data)

df = pd.concat(df)
df
# Out:
# .\files\GA_November8_2016(CountyPrecinct) ['APPLING.xlsx', 'ATKINSON.xlsx', 'BACON.xlsx', 'BAKER.xlsx', 'BALDWIN.xlsx', 'BANKS.xlsx', 'BARROW.xlsx', 'BARTOW.xlsx', 'BEN HILL.xlsx', 'BERRIEN.xlsx', 'BIBB.xlsx', 'BLECKLEY.xlsx', 'BRANTLEY.xlsx', 'BROOKS.xlsx', 'BRYAN.xlsx', 'BULLOCH.xlsx', 'BURKE.xlsx', 'BUTTS.xlsx', 'CALHOUN.xlsx', 'CAMDEN.xlsx', 'CANDLER.xlsx', 'CARROLL.xlsx', 'CATOOSA.xlsx', 'CHARLTON.xlsx', 'CHATHAM.xlsx', 'CHATTAHOOCHEE.xlsx', 'CHATTOOGA.xlsx', 'CHEROKEE.xlsx', 'CLARKE.xlsx', 'CLAY.xlsx', 'CLAYTON.xlsx', 'CLINCH.xlsx', 'COBB.xlsx', 'COFFEE.xlsx', 'COLQUITT.xlsx', 'COLUMBIA.xlsx', 'COOK.xlsx', 'COWETA.xlsx', 'CRAWFORD.xlsx', 'CRISP.xlsx', 'DADE.xlsx', 'DAWSON.xlsx', 'DECATUR.xlsx', 'DEKALB.xlsx', 'DODGE.xlsx', 'DOOLY.xlsx', 'DOUGHERTY.xlsx', 'DOUGLAS.xlsx', 'EARLY.xlsx', 'ECHOLS.xlsx', 'EFFINGHAM.xlsx', 'ELBERT.xlsx', 'EMANUEL.xlsx', 'EVANS.xlsx', 'FANNIN.xlsx', 'FAYETTE.xlsx', 'FLOYD.xlsx', 'FORSYTH.xlsx', 'FRANKLIN.xlsx', 'FULTON.xlsx', 'GILMER.xlsx', 'GLASCOCK.xlsx', 'GLYNN.xlsx', 'GORDON.xlsx', 'GRADY.xlsx', 'GREENE.xlsx', 'GWINNETT.xlsx', 'HABERSHAM.xlsx', 'HALL.xlsx', 'HANCOCK.xlsx', 'HARALSON.xlsx', 'HARRIS.xlsx', 'HART.xlsx', 'HEARD.xlsx', 'HENRY.xlsx', 'HOUSTON.xlsx', 'IRWIN.xlsx', 'JACKSON.xlsx', 'JASPER.xlsx', 'JEFF DAVIS.xlsx', 'JEFFERSON.xlsx', 'JENKINS.xlsx', 'JOHNSON.xlsx', 'JONES.xlsx', 'LAMAR.xlsx', 'LANIER.xlsx', 'LAURENS.xlsx', 'LEE.xlsx', 'LIBERTY.xlsx', 'LINCOLN.xlsx', 'LONG.xlsx', 'LOWNDES.xlsx', 'LUMPKIN.xlsx', 'MACON.xlsx', 'MADISON.xlsx', 'MARION.xlsx', 'MCDUFFIE.xlsx', 'MCINTOSH.xlsx', 'MERIWETHER.xlsx', 'MILLER.xlsx', 'MITCHELL.xlsx', 'MONROE.xlsx', 'MONTGOMERY.xlsx', 'MORGAN.xlsx', 'MURRAY.xlsx', 'MUSCOGEE.xlsx', 'NEWTON.xlsx', 'OCONEE.xlsx', 'OGLETHORPE.xlsx', 'PAULDING.xlsx', 'PEACH.xlsx', 'PICKENS.xlsx', 'PIERCE.xlsx', 'PIKE.xlsx', 'POLK.xlsx', 'PULASKI.xlsx', 'PUTNAM.xlsx', 'QUITMAN.xlsx', 'RABUN.xlsx', 'RANDOLPH.xlsx', 'RICHMOND.xlsx', 'ROCKDALE.xlsx', 'SCHLEY.xlsx', 'SCREVEN.xlsx', 'SEMINOLE.xlsx', 'SPALDING.xlsx', 'STEPHENS.xlsx', 'STEWART.xlsx', 'SUMTER.xlsx', 'TALBOT.xlsx', 'TALIAFERRO.xlsx', 'TATTNALL.xlsx', 'TAYLOR.xlsx', 'TELFAIR.xlsx', 'TERRELL.xlsx', 'THOMAS.xlsx', 'TIFT.xlsx', 'TOOMBS.xlsx', 'TOWNS.xlsx', 'TREUTLEN.xlsx', 'TROUP.xlsx', 'TURNER.xlsx', 'TWIGGS.xlsx', 'UNION.xlsx', 'UPSON.xlsx', 'WALKER.xlsx', 'WALTON.xlsx', 'WARE.xlsx', 'WARREN.xlsx', 'WASHINGTON.xlsx', 'WAYNE.xlsx', 'WEBSTER.xlsx', 'WHEELER.xlsx', 'WHITE.xlsx', 'WHITFIELD.xlsx', 'WILCOX.xlsx', 'WILKES.xlsx', 'WILKINSON.xlsx', 'WORTH.xlsx']
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in radd(left, right)
#       8 def radd(left, right):
# ----> 9     return right + left
#      10
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U21'), dtype('<U21')) -> dtype('<U21')
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-4-f407c6043af4> in <module>
#      20     data = pd.read_excel(f, 'DEMOGRAPHICS REPORT', header=None, names=voter_cols, index_col=0,  usecols=column_range, skiprows=3)
#      21
# ---> 22     indexName = (basename(f[:-5])) + '-' + (data['Precinct'])
#      23     county = (basename(f[:-5]))
#      24 #     data.loc[f'{county}-Total'] = data.sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     498         lvalues = extract_array(left, extract_numpy=True)
#     499         rvalues = extract_array(right, extract_numpy=True)
# --> 500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
#     502         return _construct_result(left, result, index=left.index, name=res_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
# --> 151         result = masked_arith_op(left, right, op)
#     152
#     153     return missing.dispatch_fill_zeros(op, left, right, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in radd(left, right)
#       7
#       8 def radd(left, right):
# ----> 9     return right + left
#      10
#      11
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U21'), dtype('<U21')) -> dtype('<U21')

# %%
df.to_excel(f'./files/Stripped-Data/ALL-Georgia.xlsx')
df.to_excel(f'./files/Stripped-Data/ALL-Georgia_CountyTotals.xlsx')
